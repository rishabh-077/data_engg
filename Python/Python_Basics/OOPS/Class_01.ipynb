# %%
OOP Introduction
Class vs Object
Constructors and self
Types of variables
    Class Variables
    Instance Variables
Types of Methods
    Class methods
    Instance Methods
Encapsulation
    Setter and Getter
    Property
Polymorphism 
    Duck Typing
    Overloading
    Overriding
Inheritance
    Types of Inheritance
    super()
    MRO
Abstraction
Interface

# %%
Programming Paradigm
    1. Structured
    2. Procedural
    3. Functuonal
    4. Scripting
    5. OOP

# %%
OOP - Class and Object

Object Oriented Programming

Programming paradigm where everything is treated as objects.

Class - Blueprint
Object - Features and Attributes

Example of object -

# %%
# Attribute - Data or variables
# Behaviour - Method/function

# Student definition
#     Attribute - name, id, marks, addr, rollno, std, sec
#     Behaviour - talking(), walking(), sleeping(), eating()

# int class
#     Attribute - value
#     behaviour - add(), abs(), mul(), sub(), floor()
    

# In Python everything is an object.

a = 10
print(type(a))

# C, C++, Java - short, int, long - 2 byte, 4 byte, 8byte
# Python - int - 28 byte

print(id(a))

a = 10
data = 10
id = 
size
...
method
# Out:
# <class 'int'>

# %%
help(int)
# Out:
# Help on class int in module builtins:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
# ...

# %%
Class - Is a blueprint for an object
Object - is an instance of the class.

# Attribute - Data or variables
# Behaviour - Method/function

# %%
# Class Creation
# Builtin class
# Userdefined class

# Class Definition
class Student:
    '''This is my First class and we will explore the Object Oriented Programming with this example.'''
    pass

# def Student():
#     print('Student function')

# Instantitation or object creation
st1 = Student()
st2 = Student()
st3 = Student()
print(st1, type(st1))

# Accessing the documentation
print(Student.__doc__)


# Adding the attribute to the object
st1.name = 'Abhishek'
st2.name = 'Roshni'
st3.name = 'Abdul'

print(st1.name)
print(st2.name)
print(st3.name)

for each student name, roll, marks, father, mother - 500
# Out:
# <__main__.Student object at 0x10323f040> <class '__main__.Student'>
# This is my First class and we will explore the Object Oriented Programming with this example.
# Abhishek
# Roshni
# Abdul

# %%
a = 10
a = 'Python'
print(a)
# Out:
# Python

# %%
# Constructor - is method which is called by default when we create the object.
# __init__() - constructor
# The first argument to the constructor is always 'self'

class Student:
    def __init__(self, st_name, st_roll_no, st_marks, st_addr, st_std = 'V'):
        print(f'Starting the constructor{self}')
        self.name = st_name
        self.roll_no = st_roll_no
        self.marks = st_marks
        self.addr = st_addr
        self.std = st_std
        print(f'Stopping the constructor{self}')
        

st1 = Student('Abhishek', 101, 99, 'BLR', 'V')
print(st1)
print()
st2 = Student('Aniket', 102, 98, 'CHN', 'VI')
print(st2)
print()
st3 = Student('Anshu', 103, 99, 'KOL', 'VI')
print(st3)
print(id(st3))
print()
print(st1.name)
print(st1.roll_no)
print()
print(st2.name)
print(st2.roll_no)
print()
print(st3.name)
print(st3.roll_no)
print()





# Instance Variable - will be different for each instance
# A different copy of instance variable will be shared with each instance of the class.
# Out:
# Starting the constructor<__main__.Student object at 0x10323f5e0>
# Stopping the constructor<__main__.Student object at 0x10323f5e0>
# ...
#
# Starting the constructor<__main__.Student object at 0x10322cb80>
# Stopping the constructor<__main__.Student object at 0x10322cb80>
# ...
#
# Starting the constructor<__main__.Student object at 0x10322c790>
# Stopping the constructor<__main__.Student object at 0x10322c790>
# ...
# 4347578256
#
# Abhishek
# 101
#
# Aniket
# 102
#
# Anshu
# 103

# %%
a = 10
b = 20

# %%
# Class Varibale - a same copy will be shared with each instance of the class


class Student:
    lst = ['DPS']
    def __init__(self, st_name, st_roll_no, st_marks, st_addr, st_std = 'V'):
        print(f'Starting the constructor{self}')
        self.name = st_name
        self.roll_no = st_roll_no
        self.marks = st_marks
        self.addr = st_addr
        self.std = st_std
        print(f'Stopping the constructor{self}')
        
st1 = Student('Abhishek', 101, 99, 'BLR', 'V')
print(st1)
print()
st2 = Student('Aniket', 102, 98, 'CHN', 'VI')
print(st2)
print()
st3 = Student('Anshu', 103, 99, 'KOL', 'VI')
print(st3)

print(st1.lst, id(st1.lst))
print(st2.lst, id(st2.lst))
print(st3.lst, id(st3.lst))

st1.lst.append('YPS')

  
print(st1.lst, id(st1.lst))
print(st2.lst, id(st2.lst))
print(st3.lst, id(st3.lst))
# Out:
# Starting the constructor<__main__.Student object at 0x1029ac640>
# Stopping the constructor<__main__.Student object at 0x1029ac640>
# ...
#
# Starting the constructor<__main__.Student object at 0x1029acd30>
# Stopping the constructor<__main__.Student object at 0x1029acd30>
# ...
#
# Starting the constructor<__main__.Student object at 0x1029ac700>
# Stopping the constructor<__main__.Student object at 0x1029ac700>
# ...
# ['DPS'] 4349021568
# ['DPS'] 4349021568
# ['DPS'] 4349021568
# ['DPS', 'YPS'] 4349021568
# ['DPS', 'YPS'] 4349021568
# ['DPS', 'YPS'] 4349021568

# %%
Create a contact class
Define a constructore





Create 5 contact objects
Each object will take name, mob, email while creating the object
There is contact list as class variable where the contact object will be appended at the time of instantiation,

# %%
class Contact:
    '''This is the contact list. It also contains the list of Contact objects as a class level variable'''
    contact_list = []
    def __init__(self,name,mobile,email):
        print("Starting the constructor")
        self.name = name
        self.mobile = mobile
        self.email = email
        self.contact_list.append(self)
        print("Stopping the constructor")
        
contact1 = Contact('Madhav',9977668855,'madhav@gmail.com')
print(f"Contact1 name: {contact1.name} Id:{id(contact1)}")      
print(f"Name of 1st object in contact_list: {contact1.contact_list[0].name}")
print()
contact2 = Contact('Nithesh',9876672355,'nithesh@gmail.com')
print(f"Contact2 name: {contact2.name} Id:{id(contact2)}")      
print(f"Name of 2nd object in contact_list: {contact2.contact_list[1].name}")
print()
contact3 = Contact('Remya',9523487685,'remya@gmail.com')
print(f"Contact3 name: {contact3.name} Id:{id(contact3)}")      
print(f"Name of 3rd object in contact_list: {contact3.contact_list[2].name}")
print()
contact4 = Contact('Aditi',9520020685,'aditi@gmail.com')
print(f"Contact4 name: {contact4.name} Id:{id(contact4)}")      
print(f"Name of 4th object in contact_list: {contact4.contact_list[3].name}")
print()
contact5 = Contact('Ankita',9973121415,'ankita@gmail.com')
print(f"Contact5 name: {contact5.name} Id:{id(contact5)}")      
print(f"Name of 5th object in contact_list: {contact5.contact_

# %%
class contact:
    '''This is to create and contact list'''
    contact_lst = []
    def __init__(self,name,mob_no,email):
        self.name = name
        self.mob_no = mob_no
        self.email = email
        self.contact_lst.append(self)

cont1 = contact('a',1234567890,'a@gmailcom')
cont2 = contact('b',986543210, 'b@rediffmail.com')
print (cont1.contact_lst)
